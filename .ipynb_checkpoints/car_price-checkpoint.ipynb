# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('car_price_prediction.csv')
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4

# %%
df.shape
# Out:
# (19237, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
#  16  Color             19237 non-null  object
#  17  Airbags           19237 non-null  int64
# dtypes: float64(1), int64(4), object(13)
# memory usage: 2.6+ MB

# %%
df.describe().T
# Out:
#               count          mean            std         min         25%  \
# ID          19237.0  4.557654e+07  936591.422799  20746880.0  45698374.0
# Price       19237.0  1.855593e+04  190581.269684         1.0      5331.0
# Prod. year  19237.0  2.010913e+03       5.668673      1939.0      2009.0
# Cylinders   19237.0  4.582991e+00       1.199933         1.0         4.0
# Airbags     19237.0  6.582627e+00       4.320168         0.0         4.0
#
#                    50%         75%         max
# ID          45772308.0  45802036.0  45816654.0
# Price          13172.0     22075.0  26307500.0
# Prod. year      2012.0      2015.0      2020.0
# Cylinders          4.0         4.0        16.0
# Airbags            6.0        12.0        16.0

# %%
df.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
df.nunique()
# Out:
# ID                  18924
# Price                2315
# Levy                  559
# Manufacturer           65
# Model                1590
# Prod. year             54
# Category               11
# Leather interior        2
# Fuel type               7
# Engine volume         107
# Mileage              7687
# Cylinders              13
# Gear box type           4
# Drive wheels            3
# Doors                   3
# Wheel                   2
# Color                  16
# Airbags                17
# dtype: int64

# %%
df['Manufacturer'].value_counts()
# Out:
# Manufacturer
# HYUNDAI          3769
# TOYOTA           3662
# MERCEDES-BENZ    2076
# FORD             1111
# CHEVROLET        1069
#                  ...
# TESLA               1
# PONTIAC             1
# SATURN              1
# ASTON MARTIN        1
# GREATWALL           1
# Name: count, Length: 65, dtype: int64

# %%
df['Manufacturer'].unique()
# Out:
# array(['LEXUS', 'CHEVROLET', 'HONDA', 'FORD', 'HYUNDAI', 'TOYOTA',
#        'MERCEDES-BENZ', 'OPEL', 'PORSCHE', 'BMW', 'JEEP', 'VOLKSWAGEN',
#        'AUDI', 'RENAULT', 'NISSAN', 'SUBARU', 'DAEWOO', 'KIA',
#        'MITSUBISHI', 'SSANGYONG', 'MAZDA', 'GMC', 'FIAT', 'INFINITI',
#        'ALFA ROMEO', 'SUZUKI', 'ACURA', 'LINCOLN', 'VAZ', 'GAZ',
#        'CITROEN', 'LAND ROVER', 'MINI', 'DODGE', 'CHRYSLER', 'JAGUAR',
#        'ISUZU', 'SKODA', 'DAIHATSU', 'BUICK', 'TESLA', 'CADILLAC',
#        'PEUGEOT', 'BENTLEY', 'VOLVO', 'სხვა', 'HAVAL', 'HUMMER', 'SCION',
#        'UAZ', 'MERCURY', 'ZAZ', 'ROVER', 'SEAT', 'LANCIA', 'MOSKVICH',
#        'MASERATI', 'FERRARI', 'SAAB', 'LAMBORGHINI', 'ROLLS-ROYCE',
#        'PONTIAC', 'SATURN', 'ASTON MARTIN', 'GREATWALL'], dtype=object)

# %%
cat_col = [col for col in df.columns if df[col].dtype == 'O']
cat_col
# Out:
# ['Levy',
#  'Manufacturer',
#  'Model',
#  'Category',
#  'Leather interior',
#  'Fuel type',
#  'Engine volume',
#  'Mileage',
#  'Gear box type',
#  'Drive wheels',
#  'Doors',
#  'Wheel',
#  'Color']

# %%
num_col = [col for col in df.columns if df[col].dtype != 'O']
num_col
# Out:
# ['Price', 'Prod. year', 'Mileage', 'Cylinders', 'Airbags']

# %%
sns.countplot(x='Fuel type',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='Category',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.lineplot(x=df["Cylinders"],y=df["Mileage"])
# Out:
# <Axes: xlabel='Cylinders', ylabel='Mileage'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
# df=df.drop(columns=['ID','Levy','Model','Drive wheels','Doors','Wheel'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 df=df.drop(columns=['ID','Levy','Model','Drive wheels','Doors','Wheel'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['ID', 'Levy', 'Model', 'Drive wheels', 'Doors', 'Wheel'] not found in axis"

# %%
df.head()
# Out:
#    Price Manufacturer  Prod. year   Category Leather interior Fuel type  \
# 0  13328        LEXUS        2010       Jeep              Yes    Hybrid
# 1  16621    CHEVROLET        2011       Jeep               No    Petrol
# 2   8467        HONDA        2006  Hatchback               No    Petrol
# 3   3607         FORD        2011       Jeep              Yes    Hybrid
# 4  11726        HONDA        2014  Hatchback              Yes    Petrol
#
#   Engine volume  Mileage  Cylinders Gear box type   Color  Airbags
# 0           3.5   186005        6.0     Automatic  Silver       12
# 1             3   192000        6.0     Tiptronic   Black        8
# 2           1.3   200000        4.0      Variator   Black        2
# 3           2.5   168966        4.0     Automatic   White        0
# 4           1.3    91901        4.0     Automatic  Silver        4

# %%
int(df['Mileage'][0].split()[0])
# Out:
# 186005

# %%
def conv(data):
    data=int(data.split()[0])
    return data

# %%
conv("19099 km")
# Out:
# 19099

# %%
df['Mileage']=df.Mileage.apply(conv)

# %%
df.head()
# Out:
#    Price Manufacturer  Prod. year   Category Leather interior Fuel type  \
# 0  13328        LEXUS        2010       Jeep              Yes    Hybrid
# 1  16621    CHEVROLET        2011       Jeep               No    Petrol
# 2   8467        HONDA        2006  Hatchback               No    Petrol
# 3   3607         FORD        2011       Jeep              Yes    Hybrid
# 4  11726        HONDA        2014  Hatchback              Yes    Petrol
#
#   Engine volume  Mileage  Cylinders Gear box type   Color  Airbags
# 0           3.5   186005        6.0     Automatic  Silver       12
# 1             3   192000        6.0     Tiptronic   Black        8
# 2           1.3   200000        4.0      Variator   Black        2
# 3           2.5   168966        4.0     Automatic   White        0
# 4           1.3    91901        4.0     Automatic  Silver        4

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
encoder.fit_transform(df['Color'])
# Out:
# array([12,  1,  1, ...,  7,  1, 14])

# %%
cat_col = [col for col in df.columns if df[col].dtype == 'O']
cat_col
# Out:
# ['Manufacturer',
#  'Category',
#  'Leather interior',
#  'Fuel type',
#  'Engine volume',
#  'Gear box type',
#  'Color']

# %%
for col in cat_col:
    df[col] = encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#    Price  Manufacturer  Prod. year  Category  Leather interior  Fuel type  \
# 0  13328            32        2010         4                 1          2
# 1  16621             8        2011         4                 0          5
# 2   8467            21        2006         3                 0          5
# 3   3607            16        2011         4                 1          2
# 4  11726            21        2014         3                 1          5
#
#    Engine volume  Mileage  Cylinders  Gear box type  Color  Airbags
# 0             63   186005        6.0              0     12       12
# 1             56   192000        6.0              2      1        8
# 2             22   200000        4.0              3      1        2
# 3             46   168966        4.0              0     14        0
# 4             22    91901        4.0              0     12        4

# %%
df.dtypes
# Out:
# Price                 int64
# Manufacturer          int32
# Prod. year            int64
# Category              int32
# Leather interior      int32
# Fuel type             int32
# Engine volume         int32
# Mileage               int64
# Cylinders           float64
# Gear box type         int32
# Color                 int32
# Airbags               int64
# dtype: object

# %%
df.corr()
# Out:
#                      Price  Manufacturer  Prod. year  Category  \
# Price             1.000000     -0.003886    0.012982 -0.019721
# Manufacturer     -0.003886      1.000000   -0.050922 -0.038340
# Prod. year        0.012982     -0.050922    1.000000  0.071538
# Category         -0.019721     -0.038340    0.071538  1.000000
# Leather interior  0.000754     -0.174997    0.390066  0.091701
# Fuel type        -0.012419     -0.086630    0.058961  0.112440
# Engine volume     0.009039     -0.044986   -0.032897  0.011428
# Mileage          -0.001758      0.012479   -0.063501  0.008126
# Cylinders         0.007518     -0.089523   -0.096797 -0.066238
# Gear box type     0.016340      0.055909   -0.217766 -0.011968
# Color            -0.010295      0.032720    0.009943 -0.019184
# Airbags          -0.012824      0.180210    0.236969  0.131772
#
#                   Leather interior  Fuel type  Engine volume   Mileage  \
# Price                     0.000754  -0.012419       0.009039 -0.001758
# Manufacturer             -0.174997  -0.086630      -0.044986  0.012479
# Prod. year                0.390066   0.058961      -0.032897 -0.063501
# Category                  0.091701   0.112440       0.011428  0.008126
# Leather interior          1.000000  -0.029814       0.285960 -0.034379
# Fuel type                -0.029814   1.000000       0.007755 -0.015306
# Engine volume             0.285960   0.007755       1.000000 -0.006014
# Mileage                  -0.034379  -0.015306      -0.006014  1.000000
# Cylinders                 0.202473   0.081037       0.785084 -0.001768
# Gear box type            -0.288992   0.098677      -0.002778  0.016299
# Color                    -0.055987  -0.077919      -0.127168 -0.012593
# Airbags                   0.165023   0.081676       0.241104 -0.009201
#
#                   Cylinders  Gear box type     Color   Airbags
# Price              0.007518       0.016340 -0.010295 -0.012824
# Manufacturer      -0.089523       0.055909  0.032720  0.180210
# Prod. year        -0.096797      -0.217766  0.009943  0.236969
# Category          -0.066238      -0.011968 -0.019184  0.131772
# Leather interior   0.202473      -0.288992 -0.055987  0.165023
# Fuel type          0.081037       0.098677 -0.077919  0.081676
# Engine volume      0.785084      -0.002778 -0.127168  0.241104
# Mileage           -0.001768       0.016299 -0.012593 -0.009201
# Cylinders          1.000000       0.058432 -0.121727  0.176868
# Gear box type      0.058432       1.000000 -0.039952  0.107086
# Color             -0.121727      -0.039952  1.000000 -0.075554
# Airbags            0.176868       0.107086 -0.075554  1.000000

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#               Price  Manufacturer    Prod. year      Category  \
# count  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   1.855593e+04     33.080678   2010.912824      6.265582
# std    1.905813e+05     17.766465      5.668673      2.790570
# min    1.000000e+00      0.000000   1939.000000      0.000000
# 25%    5.331000e+03     21.000000   2009.000000      4.000000
# 50%    1.317200e+04     32.000000   2012.000000      7.000000
# 75%    2.207500e+04     54.000000   2015.000000      9.000000
# max    2.630750e+07     64.000000   2020.000000     10.000000
#
#        Leather interior     Fuel type  Engine volume       Mileage  \
# count      19237.000000  19237.000000   19237.000000  1.923700e+04
# mean           0.725373      3.432396      41.462234  1.532236e+06
# std            0.446338      1.807388      15.315334  4.840387e+07
# min            0.000000      0.000000       0.000000  0.000000e+00
# 25%            0.000000      2.000000      32.000000  7.013900e+04
# 50%            1.000000      5.000000      36.000000  1.260000e+05
# 75%            1.000000      5.000000      46.000000  1.888880e+05
# max            1.000000      6.000000     106.000000  2.147484e+09
#
#           Cylinders  Gear box type         Color       Airbags
# count  19237.000000   19237.000000  19237.000000  19237.000000
# mean       4.582991       0.536310      7.776005      6.582627
# std        1.199933       0.896607      5.363884      4.320168
# min        1.000000       0.000000      0.000000      0.000000
# 25%        4.000000       0.000000      1.000000      4.000000
# 50%        4.000000       0.000000      7.000000      6.000000
# 75%        4.000000       1.000000     12.000000     12.000000
# max       16.000000       3.000000     15.000000     16.000000

# %%
Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)
IQR = Q3 - Q1

# %%
df.shape
# Out:
# (19237, 12)

# %%
df[~((df['Price'] < (Q1 - 1.5 * IQR)) | (df['Price'] > (Q3 + 1.5 * IQR)))]
# Out:
#        Price  Manufacturer  Prod. year  Category  Leather interior  Fuel type  \
# 0      13328            32        2010         4                 1          2
# 1      16621             8        2011         4                 0          5
# 2       8467            21        2006         3                 0          5
# 3       3607            16        2011         4                 1          2
# 4      11726            21        2014         3                 1          5
# ...      ...           ...         ...       ...               ...        ...
# 19232   8467            36        1999         1                 1          0
# 19233  15681            23        2011         9                 1          5
# 19234  26108            23        2010         4                 1          1
# 19235   5331             8        2007         4                 1          1
# 19236    470            23        2012         9                 1          2
#
#        Engine volume  Mileage  Cylinders  Gear box type  Color  Airbags
# 0                 63   186005        6.0              0     12       12
# 1                 56   192000        6.0              2      1        8
# 2                 22   200000        4.0              3      1        2
# 3                 46   168966        4.0              0     14        0
# 4                 22    91901        4.0              0     12        4
# ...              ...      ...        ...            ...    ...      ...
# 19232             37   300000        4.0              1     12        5
# 19233             44   161600        4.0              2     11        8
# 19234             36   116365        4.0              0      7        4
# 19235             36    51258        4.0              0      1        4
# 19236             44   186923        4.0              0     14       12
#
# [18164 rows x 12 columns]

# %%
df.corr()
# Out:
#                      Price  Manufacturer  Prod. year  Category  \
# Price             1.000000     -0.003886    0.012982 -0.019721
# Manufacturer     -0.003886      1.000000   -0.050922 -0.038340
# Prod. year        0.012982     -0.050922    1.000000  0.071538
# Category         -0.019721     -0.038340    0.071538  1.000000
# Leather interior  0.000754     -0.174997    0.390066  0.091701
# Fuel type        -0.012419     -0.086630    0.058961  0.112440
# Engine volume     0.009039     -0.044986   -0.032897  0.011428
# Mileage          -0.001758      0.012479   -0.063501  0.008126
# Cylinders         0.007518     -0.089523   -0.096797 -0.066238
# Gear box type     0.016340      0.055909   -0.217766 -0.011968
# Color            -0.010295      0.032720    0.009943 -0.019184
# Airbags          -0.012824      0.180210    0.236969  0.131772
#
#                   Leather interior  Fuel type  Engine volume   Mileage  \
# Price                     0.000754  -0.012419       0.009039 -0.001758
# Manufacturer             -0.174997  -0.086630      -0.044986  0.012479
# Prod. year                0.390066   0.058961      -0.032897 -0.063501
# Category                  0.091701   0.112440       0.011428  0.008126
# Leather interior          1.000000  -0.029814       0.285960 -0.034379
# Fuel type                -0.029814   1.000000       0.007755 -0.015306
# Engine volume             0.285960   0.007755       1.000000 -0.006014
# Mileage                  -0.034379  -0.015306      -0.006014  1.000000
# Cylinders                 0.202473   0.081037       0.785084 -0.001768
# Gear box type            -0.288992   0.098677      -0.002778  0.016299
# Color                    -0.055987  -0.077919      -0.127168 -0.012593
# Airbags                   0.165023   0.081676       0.241104 -0.009201
#
#                   Cylinders  Gear box type     Color   Airbags
# Price              0.007518       0.016340 -0.010295 -0.012824
# Manufacturer      -0.089523       0.055909  0.032720  0.180210
# Prod. year        -0.096797      -0.217766  0.009943  0.236969
# Category          -0.066238      -0.011968 -0.019184  0.131772
# Leather interior   0.202473      -0.288992 -0.055987  0.165023
# Fuel type          0.081037       0.098677 -0.077919  0.081676
# Engine volume      0.785084      -0.002778 -0.127168  0.241104
# Mileage           -0.001768       0.016299 -0.012593 -0.009201
# Cylinders          1.000000       0.058432 -0.121727  0.176868
# Gear box type      0.058432       1.000000 -0.039952  0.107086
# Color             -0.121727      -0.039952  1.000000 -0.075554
# Airbags            0.176868       0.107086 -0.075554  1.000000
