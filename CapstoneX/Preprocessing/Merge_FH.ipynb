# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0  1 Bedroom House for sale in Sector 9B Gurgaon         house
# 1                2 BHK Flat in Sector 79 Gurgaon          flat
# 2                4 BHK Flat in Sector 62 Gurgaon          flat
# 3      4 Bedroom House for sale in Surat Nagar 1         house
# 4  4 Bedroom House for sale in Sector 82 Gurgaon         house
#
#               society  price  price_per_sqft    area  \
# 0         independent   0.36          8000.0   450.0
# 1  supertech araville   0.71          5522.0  1286.0
# 2       pioneer araya   9.95         20995.0  4739.0
# 3         independent   0.45         12162.0   370.0
# 4         independent   7.00         21605.0  3240.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Built Up area: 450 (41.81 sq.m.)        1         1
# 1                 Built Up area: 1295 (120.31 sq.m.)        2         2
# 2  Super Built up area 4739(440.27 sq.m.)Carpet a...        4         6
# 3  Plot area 370(34.37 sq.m.)Carpet area: 1500 sq...        4         4
# 4                        Plot area 360(301.01 sq.m.)        4         4
#
#   balcony                      additionalRoom  \
# 0       0                       not available
# 1       0                       not available
# 2       3             pooja room,servant room
# 3       2                       not available
# 4      3+  pooja room,study room,servant room
#
#                                              address  floorNum      facing  \
# 0  Basai Village, Sector 9b, Gurgaon, Sector 9B G...       1.0         NaN
# 1  E906, Sector-79, Sector 79 Gurgaon, Gurgaon, H...       9.0         NaN
# 2                Sector 62 Gurgaon, Gurgaon, Haryana      12.0  South-East
# 3                    Surat Nagar 1, Gurgaon, Haryana       4.0       North
# 4                Sector 82 Gurgaon, Gurgaon, Haryana       1.0  North-East
#
#         agePossession                                    nearbyLocations  \
# 0           undefined  ['State bank ATM', 'Shri Multispeciality Hospi...
# 1  Under Construction  ['Petrol Pump Indian Oil', 'Petrol Pump', 'Rao...
# 2     1 to 5 Year Old  ['Paras Trinity Shopping Mall', 'Golf Course E...
# 3    5 to 10 Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 4     1 to 5 Year Old  ['Orris Community Center', 'Petrol Pump Indian...
#
#                                          description  \
# 0  4 bhk independent house for sale in gurgaon. T...
# 1  Construction linked booking. First holder. Pai...
# 2  Living at the 54 really is like living in a wo...
# 3  Strong structure..Designed and custructed unde...
# 4  1 360 sq. Yd\n2park facing villa\n3 4 bhk\n4 (...
#
#                                       furnishDetails  \
# 0  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 1                                                 []
# 2  ['6 Fan', '10 Light', '7 AC', '1 Chimney', '1 ...
# 3  ['4 Wardrobe', '4 Bed', '7 Fan', '1 Fridge', '...
# 4  ['13 Fan', '1 Exhaust Fan', '6 Geyser', '38 Li...
#
#                                             features  \
# 0                                                NaN
# 1                                                NaN
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Pr...
# 3                                  ['Water Storage']
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                               rating
# 0                                                NaN
# 1  ['Environment4 out of 5', 'Lifestyle3 out of 5...
# 2  ['Green Area5 out of 5', 'Construction4 out of...
# 3  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 4  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
df.to_csv('gurgaon_properties.csv',index=False)
