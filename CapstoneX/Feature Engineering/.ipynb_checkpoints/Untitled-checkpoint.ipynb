# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../Preprocessing/gurgaon_properties_cleaned_v2.csv')
df.shape
# Out:
# (3803, 23)

# %%
df.duplicated().sum()
# Out:
# 126

# %%
df=df.drop_duplicates()

# %%
df.head()
# Out:
#   property_type             society      sector  price  price_per_sqft  \
# 0          flat  supertech araville   sector 79   0.71          5522.0
# 1          flat       pioneer araya   sector 62   9.95         20995.0
# 2         house         independent  sector 104   0.45         12162.0
# 3         house         independent   sector 82   7.00         21605.0
# 4          flat  vipul world floors   sector 48   4.30         13870.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1286.0                 Built Up area: 1295 (120.31 sq.m.)        2
# 1  4739.0  Super Built up area 4739(440.27 sq.m.)Carpet a...        4
# 2   370.0  Plot area 370(34.37 sq.m.)Carpet area: 1500 sq...        4
# 3  3240.0                        Plot area 360(301.01 sq.m.)        4
# 4  3100.0                      Carpet area: 3100 (288 sq.m.)        4
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %% [markdown]
# ### PRICE

# %%
# outliers on the basis of price column
sns.displot(df['price'])

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 1.8

# %%
# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
outliers.head()
# Out:
#    property_type               society      sector  price  price_per_sqft  \
# 1           flat         pioneer araya   sector 62   9.95         20995.0
# 3          house           independent   sector 82   7.00         21605.0
# 7          house  suncity essel towers   sector 28   6.00         22222.0
# 10          flat        vipul belmonte   sector 53   6.00         24489.0
# 11         house       godrej meridien  sector 106   5.60         14000.0
#
#       area                                       areaWithType  bedRoom  \
# 1   4739.0  Super Built up area 4739(440.27 sq.m.)Carpet a...        4
# 3   3240.0                        Plot area 360(301.01 sq.m.)        4
# 7   2700.0                        Plot area 300(250.84 sq.m.)        4
# 10  2450.0             Super Built up area 2450(227.61 sq.m.)        3
# 11  4000.0                       Plot area 4000(371.61 sq.m.)        5
#
#     bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 435          house  arjun marg/ sector- 26 phase- 1/ golf course road
# 2633         house                                        independent
# 2123         house                                     dlf city plots
# 1588         house                                        independent
# 244          house                                   suncity township
# 310          house                             emaar the palm springs
# 852          house                                        independent
# 942          house                                 vipul tatvam villa
# 3000         house                                     dlf city plots
# 1901         house                             luxury dlf city floors
# 3506         house                                        independent
# 2836         house                                        independent
# ...

# %%
# on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %% [markdown]
# ### Price_per_sqft

# %%
sns.kdeplot(df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft.sort_values('price_per_sqft',ascending=False).head()
# Out:
#      property_type                 society     sector  price  price_per_sqft  \
# 310          house  emaar the palm springs  sector 54  24.00        600000.0
# 1949         house  dlf city plots phase 2  sector 25  10.00        400000.0
# 108          house             independent  sector 12   6.00        315789.0
# 2083         house                   ansal  sector 43   1.85        308333.0
# 60           house          uppal southend  sector 49   6.75        290948.0
#
#        area                                       areaWithType  bedRoom  \
# 310   400.0                         Plot area 400(37.16 sq.m.)        5
# 1949  250.0                         Plot area 250(23.23 sq.m.)       12
# 108   190.0  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...        9
# 2083   60.0                           Plot area 60(5.57 sq.m.)        8
# 60    232.0                         Plot area 232(21.55 sq.m.)       12
#
#       bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.kdeplot(df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 310          house        emaar the palm springs        sector 54  24.00
# 333          house                unitech escape        sector 50  10.80
# 822           flat                unitech vistas        sector 70   9.00
# 1287         house            emaar mgf marbella        sector 66  18.00
# 1588         house                   independent        sector 26  26.00
# 2054         house                  malibu towne        sector 47   8.50
# 2123         house                dlf city plots        sector 26  26.00
# 2523         house                   independent        sector 26  14.75
# 2550         house  project housing board colony        sector 31   8.00
# 3118         house            cloudnine cottages  sohna road road   5.50
# 3294         house        emaar the palm springs        sector 54  14.00
# 3325         house                   independent        sector 25  16.00
# ...

# %%
df[df['price_per_sqft']>50000].shape
# Out:
# (13, 23)

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ### AREA

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 388           flat  signature global solera 2  sector 107   0.51
# 409           flat      signature the roselia   sector 95   0.45
# 2195         house                independent   sector 50   5.00
# 3126          flat            ramsons kshitij   sector 95   0.31
# 3146          flat          hcbs sports ville  sohna road   0.35
#
#       price_per_sqft      area                           areaWithType  \
# 388              9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 409              7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 2195           232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 3126             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 3146             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 388         2         2       1       3.0       North    New Property
# ...

# %%
df[df['area'] > 100000].shape
# Out:
# (5, 23)

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
#3484,1092,2002,1357,902,221,3447,2954,2688
# Out:
#      property_type                    society           sector  price  \
# 3484         house                independent        sector 26  18.40
# 2205         house  ganpati heights apartment        sector 13   1.25
# 1092          flat                 rof ananda        sector 95   0.38
# 2002          flat                 rof ananda        sector 95   0.38
# 1979         house      dlf city plot phase 4        sector 28  13.00
# 1357          flat              pyramid elite        sector 86   0.46
# 902           flat                 rof ananda        sector 95   0.33
# 221           flat      signature the serenas       sohna road   0.28
# 2478         house                independent        sector 25   7.30
# 3447          flat            ramsons kshitij        sector 95   0.24
# 2954          flat                 rof ananda        sector 95   0.21
# 3620         house                independent        sector 57   6.25
# ...

# %%
df.drop(index=[3484,1092,2002,1357,902,221,3447,2954,2688], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 2205         house  ganpati heights apartment        sector 13   1.25
# 1979         house      dlf city plot phase 4        sector 28  13.00
# 2478         house                independent        sector 25   7.30
# 3620         house                independent        sector 57   6.25
# 2122         house                independent        sector 43   5.50
# 2710          flat                 godrej air        sector 85   2.50
# 292          house       unitech aspen greens        sector 50   6.95
# 1095          flat                godrej icon       sector 88a   1.75
# 2633         house                independent        sector 43  27.50
# 986           flat             m3m golfestate        sector 65  13.20
# 3523         house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 2205           151.0  82781.0
# 1979          1992.0  65261.0
# 2478          1560.0  46795.0
# ...

# %%
df.loc[2205,'area'] = 115*9
df.loc[1979,'area'] = 7250
df.loc[2478,'area'] = 5800
df.loc[3620,'area'] = 2660
df.loc[2122,'area'] = 2850
df.loc[2710,'area'] = 1812
df.loc[292,'area'] = 2160
df.loc[1095,'area'] = 1175

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1950.357005
# std       1215.707897
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# ### Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# => some error exist in these values becuase bedroom no. and area don't match up
# Out:
#      property_type                      society      sector  price  \
# 784          house                  independent   sector 54   5.00
# 1852         house                  independent   sector 43   4.50
# 832          house                  independent  sector 17a   3.87
# 2327         house                  independent  sector 17a   3.93
# 544          house                  independent   sector 54   5.50
# 626          house                private house   sector 55   7.05
# 46           house                  independent   sector 55   9.19
# 2021         house                  independent   sector 11   4.50
# 1901         house       luxury dlf city floors   sector 26  20.00
# 2619         house                  independent   sector 56  12.39
# 3000         house               dlf city plots   sector 26  20.00
# 3261         house                  independent   sector 40  12.00
# 3570         house                  independent   sector 43  13.50
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.203735
# std         1.393968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 121          house  adani brahma samsara  sector 60  18.02         28200.0
# 399          house           independent  sector 39   7.00         10000.0
# 3033         house           independent  sector 24  11.00         28902.0
#
#         area                                       areaWithType  bedRoom  \
# 121   6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 399   7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 3033  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 121         12      3+       3.0  North-East  Relatively New
# 399         11      3+       4.0  South-East  Relatively New
# 3033        11      3+       3.0        East    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
df.head()
# Out:
#   property_type             society      sector  price  price_per_sqft  \
# 0          flat  supertech araville   sector 79   0.71          5522.0
# 1          flat       pioneer araya   sector 62   9.95         20995.0
# 2         house         independent  sector 104   0.45         12162.0
# 3         house         independent   sector 82   7.00         21605.0
# 4          flat  vipul world floors   sector 48   4.30         13870.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1286.0                 Built Up area: 1295 (120.31 sq.m.)        2
# 1  4739.0  Super Built up area 4739(440.27 sq.m.)Carpet a...        4
# 2   370.0  Plot area 370(34.37 sq.m.)Carpet area: 1500 sq...        4
# 3  3240.0                        Plot area 360(301.01 sq.m.)        4
# 4  3100.0                      Carpet area: 3100 (288 sq.m.)        4
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 1504          flat  bestech park view grand spa    sector 81    4.7
# 1762          flat       krrish provence estate  gwal pahari    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 1504          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 1762          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1504        4         4      3+      19.0       North  Relatively New
# 1762        5         6      3+      23.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 1504               6926.0            NaN          NaN           0
# 1762              10000.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# ### built up area

# %%
sns.kdeplot(df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 8000].sort_values('built_up_area',ascending=False)
# Out:
#      property_type                  society     sector  price  price_per_sqft  \
# 2060         house              independent  sector 25   10.0         37037.0
# 324          house  ansal sushant lok plots  sector 43   11.5         17692.0
# 2809         house              dlf alameda  sector 73   17.0         35109.0
# 3207         house          anamika enclave  sector 12    6.0         14492.0
# 1366         house              independent  sector 56    8.0          9654.0
#
#         area                                       areaWithType  bedRoom  \
# 2060  2700.0  Plot area 2700(250.84 sq.m.)Built Up area: 950...        5
# 324   6500.0  Plot area 3762(349.5 sq.m.)Built Up area: 9000...        7
# 2809  4842.0  Plot area 4842(449.84 sq.m.)Built Up area: 900...        5
# 3207  4140.0  Plot area 4140(384.62 sq.m.)Built Up area: 900...        9
# 1366  8287.0  Plot area 362(33.63 sq.m.)Built Up area: 8286 ...       10
#
# ...

# %% [markdown]
# ### carpet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 986           flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
# 2710          flat      godrej air  sector 85    2.5          1379.0   1812.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 986   Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
# 2710  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 986        North      Moderately Old                  NaN            NaN
# 2710  North-East  Under Construction                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 986       11000.0           0             1           0           0       0
# 2710      18122.0           1             0           0           1       1
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[2710,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#     property_type         society     sector  price  price_per_sqft     area  \
# 986          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                            areaWithType  bedRoom  bathroom balcony  floorNum  \
# 986  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#     facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 986  North  Moderately Old                  NaN            NaN      11000.0
#
#      study room  servant room  store room  pooja room  others  \
# 986           0             1           0           0       0
#
#      furnishing_type  luxury_score
# 986                1            60

# %%
df.head()
# Out:
#   property_type             society      sector  price  price_per_sqft  \
# 0          flat  supertech araville   sector 79   0.71          5522.0
# 1          flat       pioneer araya   sector 62   9.95         20995.0
# 2         house         independent  sector 104   0.45         12162.0
# 3         house         independent   sector 82   7.00         21605.0
# 4          flat  vipul world floors   sector 48   4.30         13870.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1286.0                 Built Up area: 1295 (120.31 sq.m.)        2
# 1  4739.0  Super Built up area 4739(440.27 sq.m.)Carpet a...        4
# 2   370.0  Plot area 370(34.37 sq.m.)Carpet area: 1500 sq...        4
# 3  3240.0                        Plot area 360(301.01 sq.m.)        4
# 4  3100.0                      Carpet area: 3100 (288 sq.m.)        4
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %% [markdown]
# ### luxury score

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df.shape
# Out:
# (3588, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type             society      sector  price  price_per_sqft  \
# 0          flat  supertech araville   sector 79   0.71          5521.0
# 1          flat       pioneer araya   sector 62   9.95         20996.0
# 2         house         independent  sector 104   0.45         12162.0
# 3         house         independent   sector 82   7.00         21605.0
# 4          flat  vipul world floors   sector 48   4.30         13871.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1286.0                 Built Up area: 1295 (120.31 sq.m.)        2
# 1  4739.0  Super Built up area 4739(440.27 sq.m.)Carpet a...        4
# 2   370.0  Plot area 370(34.37 sq.m.)Carpet area: 1500 sq...        4
# 3  3240.0                        Plot area 360(301.01 sq.m.)        4
# 4  3100.0                      Carpet area: 3100 (288 sq.m.)        4
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\rubha\AppData\Local\Temp\ipykernel_8476\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 503          house                   independent   sector 26   19.0
# 1690         house                   independent   sector 43    9.5
# 1749         house                   independent   sector 55    5.0
# 1896         house                   independent   sector 28   12.0
# 2124         house                   independent  sector 105    9.9
# 2217         house                dlf city plots   sector 26   19.0
# 2423         house                   independent   sector 25   13.0
# 2841         house  sushant lok 1 builder floors   sector 43   13.0
# 3506         house                   independent   sector 26   20.0
#
#       price_per_sqft    area  \
# 503          42222.0  4500.0
# 1690         42222.0  2250.0
# 1749         44444.0  1125.0
# 1896         42194.0  2844.0
# 2124         49500.0  2000.0
# 2217         42054.0  4518.0
# 2423         45710.0  2844.0
# 2841         48148.0  2700.0
# ...

# %%
# Area per Bedroom ratio------->of 98%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.02)
# Out:
# 183.33333333333334

# %%
df[(df['area']/df['bedRoom'])<183]
# Out:
#      property_type      society      sector  price  price_per_sqft    area  \
# 2            house  independent  sector 104   0.45         12162.0   370.0
# 26           house  independent    sector 4   0.92         15257.0   603.0
# 57           house  independent    sector 8   0.49         11239.0   436.0
# 171          house  independent   sector 12   0.65          6500.0  1000.0
# 186          house    row house  sector 105   0.43          9130.0   471.0
# ...            ...          ...         ...    ...             ...     ...
# 3601         house  independent   sector 55   1.45         26852.0   540.0
# 3646         house  independent    sector 9   1.25          8735.0  1431.0
# 3682         house  independent    sector 9   0.42          9333.0   450.0
# 3749         house  independent   sector 12   0.90         13333.0   675.0
# 3784         house  independent   sector 24   4.50         33333.0  1350.0
#
# ...
