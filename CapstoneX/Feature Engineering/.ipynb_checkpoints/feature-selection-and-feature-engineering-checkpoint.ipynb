# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_missing_value_imputation.csv')

# %%
df.shape
# Out:
# (3554, 18)

# %%
df.head()
# Out:
#   property_type             society     sector  price  price_per_sqft  \
# 0          flat  supertech araville  sector 79   0.71          5521.0
# 1          flat       pioneer araya  sector 62   9.95         20996.0
# 2         house         independent  sector 82   7.00         21605.0
# 3          flat  vipul world floors  sector 48   4.30         13871.0
# 4          flat         godrej aria  sector 79   1.30          9623.0
#
#    bedRoom  bathroom balcony  floorNum       agePossession  built_up_area  \
# 0        2         2       0       9.0  Under Construction         1295.0
# 1        4         6       3      12.0      Relatively New         3933.0
# 2        4         4      3+       1.0      Relatively New         3240.0
# 3        4         5      3+       4.0        New Property         3444.0
# 4        2         4       2       3.0      Relatively New         1223.0
#
#    study room  servant room  store room  pooja room  others  furnishing_type  \
# 0           0             0           0           0       0                1
# 1           0             1           0           1       0                0
# 2           1             1           0           1       0                0
# 3           1             1           0           1       0                1
# 4           0             0           0           0       0                1
#
#    luxury_score
# 0             0
# 1           138
# 2            49
# 3            88
# 4            53

# %%
train_df = df.drop(columns=['society','price_per_sqft'])

# %%
train_df.head()
# Out:
#   property_type     sector  price  bedRoom  bathroom balcony  floorNum  \
# 0          flat  sector 79   0.71        2         2       0       9.0
# 1          flat  sector 62   9.95        4         6       3      12.0
# 2         house  sector 82   7.00        4         4      3+       1.0
# 3          flat  sector 48   4.30        4         5      3+       4.0
# 4          flat  sector 79   1.30        2         4       2       3.0
#
#         agePossession  built_up_area  study room  servant room  store room  \
# 0  Under Construction         1295.0           0             0           0
# 1      Relatively New         3933.0           0             1           0
# 2      Relatively New         3240.0           1             1           0
# 3        New Property         3444.0           1             1           0
# 4      Relatively New         1223.0           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1             0
# 1           1       0                0           138
# 2           1       0                0            49
# 3           1       0                1            88
# 4           0       0                1            53

# %%
sns.heatmap(train_df.select_dtypes(include=['number']) .corr())
# Out:
# <Axes: >

# %%
train_df.select_dtypes(include=['number']).corr()['price'].sort_values(ascending=False)
# Out:
# price              1.000000
# built_up_area      0.744312
# bathroom           0.609777
# bedRoom            0.591289
# servant room       0.391930
# pooja room         0.319852
# store room         0.305677
# study room         0.242955
# luxury_score       0.091473
# others            -0.013064
# floorNum          -0.087442
# furnishing_type   -0.111992
# Name: price, dtype: float64

# %%
# cols in question

# numerical -> luxury_score, others, floorNum
# categorical -> property_type, sector, agePossession
